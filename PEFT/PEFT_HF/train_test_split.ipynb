# %% [markdown]
# ### This notebook aims to create a train/test split of Karolina's LEK dataset.

# %%
import pandas as pd
import re

# %%
# Data loading
file_path = '/code/self-explanation/thesis_answers.csv'

# Read the CSV file using pandas with semicolon as delimiter
df = pd.read_csv(file_path, delimiter=';')

# 975 datapoints
df.head()
# Out:
#                                             Question Version  Year  \
# 0  A 66-year-old male who has been treated only f...  Spring  2021
# 1  An absolute contraindication to fibrynolysis i...  Spring  2021
# 2  Hypercalcemia related to malignancy: A. is mos...  Spring  2021
# 3  Lung cancer in Poland: A. is the most common m...  Spring  2021
# 4  Cancer of unknown primary site: A. is found in...  Spring  2021
#
#              Category Answer    %A    %B    %C    %D    %E  ...  \
# 0  Internal Dieseases      C   9.7  18.7  38.6  25.7   7.5  ...
# 1  Internal Dieseases      A  61.2   6.2   1.5   9.4  20.9  ...
# 2  Internal Dieseases      B   2.4  52.4   1.3  39.1   4.8  ...
# 3  Internal Dieseases      D   1.7   1.1   3.4  37.4  56.4  ...
# 4  Internal Dieseases      D   6.3  19.0   5.0  38.1  31.6  ...
#
#    Prompt_1_Llama_13b  GPT 4  GPT 3  Bard  Vicuna 7B  Vicuna 13B  Vicuna 33B  \
# 0                   0      C      D     C          A           B           B
# 1                   0      E      E     E          E           E           E
# 2                   0      B      D     D          D           D           D
# 3                   0      D      D     E          D           D           D
# 4                   0      D      D     D          D           D           E
#
#   Llama 7B Llama 13B Llama 70B
# 0        0         C         C
# 1        0         E         C
# 2        0         D         D
# 3        0         D         D
# 4        D         D         E
#
# [5 rows x 32 columns]

# %% [markdown]
# ### Data processing

# %%
# Create option columns 'A', 'B', 'C', 'D' in the df
def split_question_options(row):
    text = row['Question']
    pattern = r"^(.*?)\s*A\.\s*(.*?)\s*B\.\s*(.*?)\s*C\.\s*(.*?)\s*D\.\s*(.*?)\s*(?:E\.\s*(.*?))?\s*$"
    match = re.match(pattern, text)
    if match:
        question, option_a, option_b, option_c, option_d, *option_e = match.groups()
        option_e = option_e[0] if option_e else ""  # Handle optional option E
        return pd.Series([question, option_a, option_b, option_c, option_d, option_e, row['Answer']])
    else:
        return pd.Series([text, "", "", "", "", "", row['Answer']])

# Apply the function to each row
split_df = df.apply(split_question_options, axis=1)

# Rename columns and reset index
split_df.columns = ['prompt', 'A', 'B', 'C', 'D', 'E', 'answer']
split_df = split_df.reset_index().rename(columns={'index': 'index'})

split_df.head()
# Out:
#    index                                             prompt  \
# 0      0  A 66-year-old male who has been treated only f...
# 1      1   An absolute contraindication to fibrynolysis is:
# 2      2               Hypercalcemia related to malignancy:
# 3      3                             Lung cancer in Poland:
# 4      4                    Cancer of unknown primary site:
#
#                                                    A  \
# 0  stop atrial fibrillation by electrical cardiov...
# 1       ischaemic stroke within the last six months.
# 2  is most frequent in patients with chronic myel...
# 3       is the most common malignant disease in men.
# 4  is found in 30% of all cases of malignant dise...
#
#                                                    B  \
# 0  stop atrial fibrillation by pharmacotherapy, r...
# 1                                         pregnancy.
# 2          may be related to parathormone secretion.
# 3  is the most common cause of cancer-related dea...
# 4  at least half of the cases have morphology of ...
#
#                                                    C  \
# 0  slow down HR to the safe and well-tolerated le...
# 1                           infectious endocarditis.
# 2  should always be treated with oral biphosphona...
# 3  is the most common cause of cancer-related dea...
# 4         should be diagnosed using immunochemistry.
#
#                                                    D  \
# 0  slow down HR to the safe and well-tolerated le...
# 1                       active peptic ulcer disease.
# 2                       answers A and B are correct.
# 3                       answers B and C are correct.
# 4                       answers B and C are correct.
#
#                                                    E answer
# 0  refer the patient to cardiology dept. for urge...      C
# 1                                  all of the above.      A
# 2                   answers A, B, and C are correct.      B
# 3                       answers A, B, C are correct.      D
# 4                   answers A, B, and C are correct.      D

# %%
from sklearn.model_selection import train_test_split

# Splitting the DataFrame into 80% train and 20% test
train_df, test_df = train_test_split(split_df, test_size=0.20, random_state=42)

# Checking the size of the resulting train and test DataFrames
train_size = len(train_df)
test_size = len(test_df)

train_size, test_size
# Out:
# (780, 195)

# %%
train_df.head()
# Out:
#      index                                             prompt  \
# 969    969  A potential relationship between a given disea...
# 678    678  Which of the following is not an indication fo...
# 894    894  A patient presents to the gynaecological outpa...
# 33      33                       Superior vena cava syndrome:
# 31      31  The treatment of acute hyperkalemia includes t...
#
#                                                      A  \
# 969                             cross-sectional study.
# 678                 post-inflammatory liver cirrhosis.
# 894                                overactive bladder.
# 33   most commonly occurs in the course of lung can...
# 31                                              1,5,6.
#
#                                                      B  \
# 969                                case-control study.
# 678                              Budd-Chiari syndrome.
# 894  exercise-induced urinary incontinence caused b...
# 33           may be associated with vessel thrombosis.
# 31                                              2,4,5.
#
#                                                      C  \
# 969                                  ecological study.
# 678                                  Wilson’s disease.
# 894                        mixed urinary incontinence.
# 33   is a contraindication to the use of corticoste...
# 31                                              3,5,6.
#
#                                                      D  \
# 969                               correlational study.
# 678     primary and secondary biliary liver cirrhosis.
# 894  evacuation of accumulated lymph fluid through ...
# 33                                A and B are correct.
# 31                                              2,3,6.
#
#                                           E answer
# 969                      descriptive study.      B
# 678  disseminated hepatocellular carcinoma.      E
# 894                  vesicovaginal fistula.      E
# 33                  A, B and C are correct.      D
# 31                                   1,3,6.      D

# %%
# Saving the train_df and test_df to local CSV files
train_df.to_csv('/code/llm-fine-tuning/llm_finetuning/thesis_questions_train.csv', index=False)
test_df.to_csv('/code/llm-fine-tuning/llm_finetuning/thesis_questions_test.csv', index=False)

# %% [markdown]
# # Check alignment between pre-trained answers using perplexity ranking with Karo results

# %%
test_df = pd.read_csv('/code/llm-fine-tuning/llm_finetuning/thesis_questions_test.csv')

# %%
test_df.head()
# Out:
#    index                                             prompt  \
# 0    199                           The HLY indicator means:
# 1    789  The symptoms of sarcoidosis include: 1) skin l...
# 2    174  CURB-65 score facilitates making decision on t...
# 3    467  The absolute indications for the surgical trea...
# 4     66  Fever and small itchy blisters that form crust...
#
#                                                    A  \
# 0                           human development index.
# 1                                           1,2,3,6.
# 2                              urinary incontinence.
# 3  lack of improvement after conservative treatment.
# 4                              erythema infectiosum.
#
#                                B                                  C  \
# 0            healthy life years.       quality-adjusted life years.
# 1                           4,9.                             2,3,9.
# 2                   pneumonitis.                acute pancreatitis.
# 3  infected pancreatic necrosis.  bleeding to the abdominal cavity.
# 4                      impetigo.                     HSV infection.
#
#                                D                                E answer
# 0             metric area index.   humanitarian list of the year.      B
# 1                       3,6,8,9.                   all the above.      E
# 2         ischemic brain stroke.                     myocarditis.      B
# 3  gastrointestinal perforation.  abdominal compartment syndrome.      A
# 4                    chickenpox.                         measles.      D

# %%
# Load my results on LLMs using perplexity ranking
results_df = pd.read_csv('/code/llm-fine-tuning/llm_finetuning/test_results.csv')
results_df = results_df[['index', 'llama2_7B_pt_top3', 'llama2_7B_chat_pt_top3', 'vicuna_7B_pt_top3']]

# %%
results_df['llama2_7B_pt_top1'] = results_df['llama2_7B_pt_top3'].str[0]
results_df['llama2_7B_chat_pt_top1'] = results_df['llama2_7B_chat_pt_top3'].str[0]
results_df['vicuna_7B_pt_top1'] = results_df['vicuna_7B_pt_top3'].str[0]

# %%
results_df.head()
# Out:
#    index llama2_7B_pt_top3 llama2_7B_chat_pt_top3 vicuna_7B_pt_top3  \
# 0    199             B A D                  B E C             B C A
# 1    789             E D B                  E A D             E D C
# 2    174             E B C                  C B E             C A D
# 3    467             B E D                  B A E             B D A
# 4     66             B E D                  B A E             B A C
#
#   llama2_7B_pt_top1 llama2_7B_chat_pt_top1 vicuna_7B_pt_top1
# 0                 B                      B                 B
# 1                 E                      E                 E
# 2                 E                      C                 C
# 3                 B                      B                 B
# 4                 B                      B                 B

# %%
# Load Karo's results on LLMs for directly generating response
file_path = '/code/self-explanation/thesis_answers.csv'

# Read the CSV file using pandas with semicolon as delimiter
karo_df = pd.read_csv(file_path, delimiter=';')
karo_df = karo_df[['Llama 7B', 'Vicuna 7B']]
karo_df.reset_index(inplace=True) # Add an 'index' column
karo_df = karo_df.rename(columns={'Llama 7B': 'Karo_llama2_7B', 'Vicuna 7B': 'Karo_vicuna_7B'})

# 975 datapoints
karo_df.head()
# Out:
#    index Karo_llama2_7B Karo_vicuna_7B
# 0      0              0              A
# 1      1              0              E
# 2      2              0              D
# 3      3              0              D
# 4      4              D              D

# %%
# Merge two dfs on the test set
merged_df = results_df.merge(karo_df, on='index', how='inner')
merged_df.head()
# Out:
#    index llama2_7B_pt_top3 llama2_7B_chat_pt_top3 vicuna_7B_pt_top3  \
# 0    199             B A D                  B E C             B C A
# 1    789             E D B                  E A D             E D C
# 2    174             E B C                  C B E             C A D
# 3    467             B E D                  B A E             B D A
# 4     66             B E D                  B A E             B A C
#
#   llama2_7B_pt_top1 llama2_7B_chat_pt_top1 vicuna_7B_pt_top1 Karo_llama2_7B  \
# 0                 B                      B                 B              0
# 1                 E                      E                 E              0
# 2                 E                      C                 C              0
# 3                 B                      B                 B              B
# 4                 B                      B                 B              0
#
#   Karo_vicuna_7B
# 0              B
# 1              E
# 2              D
# 3              B
# 4              0

# %%
# Compute percentage of matches
matches = sum((merged_df['Karo_llama2_7B'] == merged_df['llama2_7B_chat_pt_top1']) & (merged_df['Karo_llama2_7B'] != '0'))
non_zero_karo = sum(merged_df['Karo_llama2_7B'] != '0')
percentage = (matches / non_zero_karo) * 100
print(f"The percentage of matched entries in LLaMA-2-chat-7B is: {percentage}")
# Out:
# The percentage of matched entries in LLaMA-2-chat-7B is: 47.88732394366197

# %%
matches = sum((merged_df['Karo_vicuna_7B'] == merged_df['vicuna_7B_pt_top1']) & (merged_df['Karo_llama2_7B'] != '0'))
non_zero_karo = sum(merged_df['Karo_vicuna_7B'] != '0')
percentage = (matches / non_zero_karo) * 100
print(f"The percentage of matched entries in Vicuna-7B is: {percentage}")
# Out:
# The percentage of matched entries in Vicuna-7B is: 13.661202185792352
